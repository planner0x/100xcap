# %%
from math import floor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.feature_selection import chi2
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import RFE

from sklearn.model_selection import train_test_split as tts
from sklearn.model_selection import TimeSeriesSplit


from sklearn import tree
import datetime as datetime


import quandl as ql
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import brute

from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'

# %%
raw = pd.read_csv('BITFINEX_ETHUSD, 240 (1).csv')

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10439 entries, 0 to 10438
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       10439 non-null  object
#  1   open       10439 non-null  float64
#  2   high       10439 non-null  float64
#  3   low        10439 non-null  float64
#  4   close      10439 non-null  float64
#  5   EMA        10390 non-null  float64
#  6   MA         0 non-null      float64
#  7   Histogram  10406 non-null  float64
#  8   MACD       10414 non-null  float64
#  9   Signal     10406 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 815.7+ KB

# %%
data = pd.DataFrame(raw['close'])

# %%
data.rename(columns={'close':'price'},inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10439 entries, 0 to 10438
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   10439 non-null  float64
# dtypes: float64(1)
# memory usage: 81.7 KB

# %%
data['SMA1']=data['price'].rolling(21).mean()

# %%
data['SMA2']=data['price'].rolling(120).mean()

# %%
data.tail()
# Out:
#         price         SMA1         SMA2
# 10434  2112.1  2074.270995  1836.700598
# 10435  2103.5  2075.894804  1838.936573
# 10436  2073.2  2074.932899  1841.089073
# 10437  1976.9  2073.470995  1842.570740
# 10438  1982.2  2071.804328  1843.903240

# %%
# %matplotlib inline
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.family'] = 'serif'
import datetime as datetime
from datetime import datetime , timedelta 
from matplotlib import dates as mpl_dates
from pylab import mpl, plt

# %%
data.plot(title='ETH/USD | 42 & 252 days SMAs',figsize=(20,12));

# %%
data['position']=np.where(data['SMA1'] > data['SMA2'],
                         1,-1)

# %%
data.dropna(inplace=True)

# %%
data['position'].plot(ylim=[-1.1,1.1],
                     title ='Market Positioning',
                     figsize=(20,6))
# Out:
# <AxesSubplot:title={'center':'Market Positioning'}>

# %%
data['returns'] = np.log(data['price']/data['price'].shift(1))

# %%
data.tail()
# Out:
#         price         SMA1         SMA2  position   returns
# 10434  2112.1  2074.270995  1836.700598         1 -0.000994
# 10435  2103.5  2075.894804  1838.936573         1 -0.004080
# 10436  2073.2  2074.932899  1841.089073         1 -0.014509
# 10437  1976.9  2073.470995  1842.570740         1 -0.047563
# 10438  1982.2  2071.804328  1843.903240         1  0.002677

# %%
data['returns'].hist(bins=35, figsize=(20,12))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # What does the profit profile look like if we trade this strategy
# shift position column by one day to indicate our implied position for the next day
# multiply our returns column by our position column to simulate what our strategy would have returned on that day

# %%
data['strategy'] = data['position'].shift(1)*data['returns']

# %%
data[['returns','strategy']].sum()
# Out:
# returns     5.148138
# strategy    8.250720
# dtype: float64

# %%
data[['returns','strategy']].sum().apply(np.exp)
# Out:
# returns      172.110793
# strategy    3830.383600
# dtype: float64

# %%
data[['returns', 'strategy']].dropna().cumsum(
                     ).apply(np.exp).plot(figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Annualized Mean Return

# %%
data[['returns', 'strategy']].mean()* 252
# Out:
# returns     0.125723
# strategy    0.201491
# dtype: float64

# %% [markdown]
# # Annualized Standard Deviation

# %%
data[['returns', 'strategy']].std() * 252 ** 0.5
# Out:
# returns     0.352169
# strategy    0.352029
# dtype: float64

# %% [markdown]
# # Compute cumulative Return¶

# %%
data['cumret'] = data['strategy'].cumsum().apply(np.exp)

# %% [markdown]
# # Compute cumulative max

# %%
data['cummax'] =  data['cumret'].cummax()

# %% [markdown]
# # Compute the max drawdown

# %%
data[['cumret', 'cummax']].dropna().plot(figsize=(20, 12))
# Out:
# <AxesSubplot:>

# %%
drawdown = data['cummax'] - data['cumret']

# %%
drawdown.max()
# Out:
# 2437.790913100548

# %% [markdown]
# # Compute max duration of drawdown

# %%
#find the dates where drawdown is equal to 0
#these are the moments when our cumulative returns and the max cumulative returns are the same
temp = drawdown[drawdown == 0]

# %%
#compute the time difference between each of these moments in time

periods = (temp.index[1:].to_pydatetime() -
                    temp.index[:-1].to_pydatetime())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-b629ec30b7b4> in <module>
#       1 #compute the time difference between each of these moments in time
#       2
# ----> 3 periods = (temp.index[1:].to_pydatetime() -
#       4                     temp.index[:-1].to_pydatetime())
#
# AttributeError: 'Int64Index' object has no attribute 'to_pydatetime'
